# %% [markdown]
# # SCALING UP DATA ANALYSIS (Part I): FORMATS AND METHODS

# %% [markdown]
# ## FRAMEWORKS TO TEST: Pandas, Polars, DuckDB and Vaex

# %%
##  DATA:
##  https://krono.act.uji.es/IDIA/loans.csv.gz

# %%
# !pip install polars -q #new version is 0.19
# Out:
# Requirement already satisfied: polars in /usr/local/lib/python3.10/dist-packages (1.7.1)

# %%
# !pip install duckdb -q
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (1.1.1)

# %%
# %pip install vaex
# Out:
# Collecting vaex
#   Using cached vaex-4.17.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting vaex-core~=4.17.1 (from vaex)
#   Using cached vaex-core-4.17.1.tar.gz (2.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vaex-astro<0.10,>=0.9.3 (from vaex)
#   Using cached vaex_astro-0.9.3-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-hdf5<0.15,>=0.13.0 (from vaex)
#   Using cached vaex_hdf5-0.14.1-py3-none-any.whl.metadata (321 bytes)
# Collecting vaex-viz<0.6,>=0.5.4 (from vaex)
#   Using cached vaex_viz-0.5.4-py3-none-any.whl.metadata (345 bytes)
# Collecting vaex-server~=0.9.0 (from vaex)
#   Using cached vaex_server-0.9.0-py3-none-any.whl.metadata (430 bytes)
# Collecting vaex-jupyter<0.9,>=0.8.2 (from vaex)
#   Using cached vaex_jupyter-0.8.2-py3-none-any.whl.metadata (517 bytes)
# Collecting vaex-ml<0.19,>=0.18.3 (from vaex)
#   Using cached vaex_ml-0.18.3-py3-none-any.whl.metadata (485 bytes)
# Collecting astropy (from vaex-astro<0.10,>=0.9.3->vaex)
#   Using cached astropy-6.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.16 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (1.26.4)
# Collecting aplus (from vaex-core~=4.17.1->vaex)
#   Using cached aplus-0.11.0-py3-none-any.whl
# Collecting tabulate>=0.8.3 (from vaex-core~=4.17.1->vaex)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting future>=0.15.2 (from vaex-core~=4.17.1->vaex)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (6.0.2)
# Collecting progressbar2 (from vaex-core~=4.17.1->vaex)
#   Using cached progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (2.32.3)
# Requirement already satisfied: six in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (1.16.0)
# Requirement already satisfied: cloudpickle in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (3.0.0)
# Requirement already satisfied: pandas in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (2.2.3)
# Requirement already satisfied: dask!=2022.4.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (2024.9.1)
# Requirement already satisfied: nest-asyncio>=1.3.3 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (1.6.0)
# Requirement already satisfied: pyarrow>=5.0.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (17.0.0)
# Collecting frozendict!=2.2.0 (from vaex-core~=4.17.1->vaex)
#   Using cached frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting blake3 (from vaex-core~=4.17.1->vaex)
#   Using cached blake3-0.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: filelock in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (3.16.1)
# Requirement already satisfied: pydantic>=1.8.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-core~=4.17.1->vaex) (2.9.2)
# Collecting rich (from vaex-core~=4.17.1->vaex)
#   Using cached rich-13.9.2-py3-none-any.whl.metadata (18 kB)
# Collecting h5py>=2.9 (from vaex-hdf5<0.15,>=0.13.0->vaex)
#   Using cached h5py-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting bqplot>=0.10.1 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyvolume>=0.4 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvolume-0.6.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting ipyleaflet (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipympl (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting ipyvuetify<2,>=1.2.2 (from vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: xarray in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-jupyter<0.9,>=0.8.2->vaex) (2024.9.0)
# Requirement already satisfied: numba in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (0.60.0)
# Requirement already satisfied: traitlets in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (5.14.3)
# Requirement already satisfied: jinja2 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-ml<0.19,>=0.18.3->vaex) (3.1.4)
# Requirement already satisfied: tornado>4.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-server~=0.9.0->vaex) (6.4.1)
# Requirement already satisfied: cachetools in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-server~=0.9.0->vaex) (5.5.0)
# Collecting fastapi (from vaex-server~=0.9.0->vaex)
#   Using cached fastapi-0.115.2-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn[standard] (from vaex-server~=0.9.0->vaex)
#   Using cached uvicorn-0.31.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: matplotlib>=1.3.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (3.9.2)
# Requirement already satisfied: pillow in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from vaex-viz<0.6,>=0.5.4->vaex) (10.4.0)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (8.1.5)
# Collecting traittypes>=0.0.6 (from bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: click>=8.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from dask!=2022.4.0->vaex-core~=4.17.1->vaex) (8.5.0)
# Collecting ipywebrtc (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Collecting ipyvue>=1.7.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting pythreejs>=2.4.0 (from ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached pythreejs-2.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from matplotlib>=1.3.1->vaex-viz<0.6,>=0.5.4->vaex) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pandas->vaex-core~=4.17.1->vaex) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pandas->vaex-core~=4.17.1->vaex) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pydantic>=1.8.0->vaex-core~=4.17.1->vaex) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pydantic>=1.8.0->vaex-core~=4.17.1->vaex) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pydantic>=1.8.0->vaex-core~=4.17.1->vaex) (4.12.2)
# Collecting pyerfa>=2.0.1.1 (from astropy->vaex-astro<0.10,>=0.9.3->vaex)
#   Using cached pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting astropy-iers-data>=0.2024.8.27.10.28.29 (from astropy->vaex-astro<0.10,>=0.9.3->vaex)
#   Using cached astropy_iers_data-0.2024.10.14.0.32.55-py3-none-any.whl.metadata (5.1 kB)
# Collecting starlette<0.41.0,>=0.37.2 (from fastapi->vaex-server~=0.9.0->vaex)
#   Using cached starlette-0.39.2-py3-none-any.whl.metadata (6.0 kB)
# Collecting branca>=0.5.0 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting xyzservices>=2021.8.1 (from ipyleaflet->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting ipython-genutils (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: ipython<9 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (8.28.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from jinja2->vaex-ml<0.19,>=0.18.3->vaex) (2.1.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from numba->vaex-ml<0.19,>=0.18.3->vaex) (0.43.0)
# Collecting python-utils>=3.8.1 (from progressbar2->vaex-core~=4.17.1->vaex)
#   Using cached python_utils-3.9.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from requests->vaex-core~=4.17.1->vaex) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from requests->vaex-core~=4.17.1->vaex) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from requests->vaex-core~=4.17.1->vaex) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from requests->vaex-core~=4.17.1->vaex) (2024.8.30)
# Collecting markdown-it-py>=2.2.0 (from rich->vaex-core~=4.17.1->vaex)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from rich->vaex-core~=4.17.1->vaex) (2.18.0)
# Collecting h11>=0.8 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached httptools-0.6.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached uvloop-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]->vaex-server~=0.9.0->vaex)
#   Using cached websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: zipp>=3.20 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (3.20.2)
# Requirement already satisfied: decorator in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.48)
# Requirement already satisfied: stack-data in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.9,>=0.8.2->vaex) (3.0.13)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->vaex-core~=4.17.1->vaex)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: locket in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from partd>=1.4.0->dask!=2022.4.0->vaex-core~=4.17.1->vaex) (1.0.0)
# Collecting ipydatawidgets>=1.1.1 (from pythreejs>=2.4.0->ipyvolume>=0.4->vaex-jupyter<0.9,>=0.8.2->vaex)
#   Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting anyio<5,>=3.4.0 (from starlette<0.41.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex)
#   Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Collecting sniffio>=1.1 (from anyio<5,>=3.4.0->starlette<0.41.0,>=0.37.2->fastapi->vaex-server~=0.9.0->vaex)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (2.4.1)
# Requirement already satisfied: pure-eval in /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->vaex-jupyter<0.9,>=0.8.2->vaex) (0.2.3)
# Using cached vaex-4.17.0-py3-none-any.whl (4.8 kB)
# Using cached vaex_astro-0.9.3-py3-none-any.whl (20 kB)
# Using cached vaex_hdf5-0.14.1-py3-none-any.whl (16 kB)
# Using cached vaex_jupyter-0.8.2-py3-none-any.whl (43 kB)
# Using cached vaex_ml-0.18.3-py3-none-any.whl (58 kB)
# Using cached vaex_server-0.9.0-py3-none-any.whl (23 kB)
# Using cached vaex_viz-0.5.4-py3-none-any.whl (19 kB)
# Using cached bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
# Using cached frozendict-2.4.6-py311-none-any.whl (16 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached h5py-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
# Using cached ipyvolume-0.6.3-py3-none-any.whl (1.6 MB)
# Using cached ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached astropy-6.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Using cached blake3-0.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached fastapi-0.115.2-py3-none-any.whl (94 kB)
# Using cached ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Using cached ipympl-0.9.4-py3-none-any.whl (516 kB)
# Using cached progressbar2-4.5.0-py3-none-any.whl (57 kB)
# Using cached rich-13.9.2-py3-none-any.whl (242 kB)
# Using cached astropy_iers_data-0.2024.10.14.0.32.55-py3-none-any.whl (1.9 MB)
# Using cached branca-0.8.0-py3-none-any.whl (25 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached httptools-0.6.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
# Using cached ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
# Using cached jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached pyerfa-2.0.1.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached python_utils-3.9.0-py2.py3-none-any.whl (32 kB)
# Using cached pythreejs-2.4.2-py3-none-any.whl (3.4 MB)
# Using cached starlette-0.39.2-py3-none-any.whl (73 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached uvloop-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
# Using cached watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
# Using cached websockets-13.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
# Using cached xyzservices-2024.9.0-py3-none-any.whl (85 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Using cached uvicorn-0.31.1-py3-none-any.whl (63 kB)
# Using cached anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Using cached ipydatawidgets-4.3.5-py2.py3-none-any.whl (271 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Building wheels for collected packages: vaex-core
#   Building wheel for vaex-core (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for vaex-core (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [420 lines of output]
#       <string>:4: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/hash.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/utils.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/metal.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/expresso.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/grids.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataset.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/promise.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/shift.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/parallelize.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/column.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/settings.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataset_misc.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/json.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/meta.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/cpu.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/logging.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/join.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/progress.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/asyncio.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/functions.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/selections.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/geo.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/samp.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/events.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/agg.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataframe_protocol.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/delayed.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/array_types.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/encoding.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/scopes.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/serialize.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/formatting.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/groupby.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/version.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/docstrings.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/misc_cmdline.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/minisettings.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/csv.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataframe.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/multiprocessing.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/struct.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/expression.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/schema.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/datatype_test.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/memory.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/registry.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/benchmark.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/kld.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/legacy.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/itertools.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/datatype.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/rolling.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/execution.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/multithreading.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/strings.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/image.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/tasks.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataset_utils.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/_version.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/dataset_mmap.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/config.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/__main__.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/convert.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/cache.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/export.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/stat.py -> build/lib.linux-x86_64-cpython-311/vaex
#       creating build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/utils.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/dataset.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/opener.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/utils_test.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/_version.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/numpy_dispatch.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       copying vaex/arrow/convert.py -> build/lib.linux-x86_64-cpython-311/vaex/arrow
#       creating build/lib.linux-x86_64-cpython-311/vaex/core
#       copying vaex/core/_version.py -> build/lib.linux-x86_64-cpython-311/vaex/core
#       copying vaex/core/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/core
#       creating build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/column.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/gcs.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/asyncio.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/s3arrow.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/s3.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/s3fs.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/s3_test.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/cache.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       copying vaex/file/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/file
#       creating build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/misc.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/expresso.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/dataset.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/cmodule.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/plot.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/ui.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/all.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/__main__.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       copying vaex/test/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/test
#       creating build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/readcol.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/ipyvolume.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/jprops.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/common.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/bokeh.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       copying vaex/ext/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/ext
#       creating build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/parallelize.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/pandawrap.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/samp.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/progressbar.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/ordereddict.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/expressions.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       copying vaex/misc/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/misc
#       creating build/lib.linux-x86_64-cpython-311/vaex/datasets
#       copying vaex/datasets/__init__.py -> build/lib.linux-x86_64-cpython-311/vaex/datasets
#       running egg_info
#       writing vaex_core.egg-info/PKG-INFO
#       writing dependency_links to vaex_core.egg-info/dependency_links.txt
#       writing entry points to vaex_core.egg-info/entry_points.txt
#       writing requirements to vaex_core.egg-info/requires.txt
#       writing top-level names to vaex_core.egg-info/top_level.txt
#       reading manifest file 'vaex_core.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.c' under directory 'vendor'
#       warning: no files found matching '*.h' under directory 'src'
#       warning: no files found matching '*.c' under directory 'src'
#       adding license file 'LICENSE.txt'
#       writing manifest file 'vaex_core.egg-info/SOURCES.txt'
#       /tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:218: _Warning: Package 'vaex.test.files' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'vaex.test.files' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'vaex.test.files' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'vaex.test.files' to be distributed and are
#               already explicitly excluding 'vaex.test.files' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying vaex/pcre.dll -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/pcrecpp.dll -> build/lib.linux-x86_64-cpython-311/vaex
#       copying vaex/vcruntime140_1.dll -> build/lib.linux-x86_64-cpython-311/vaex
#       creating build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/gaia-small-colfits-basic.fits -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/gaia-small-colfits-plus.fits -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/gaia-small-fits-basic.fits -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/gaia-small-fits-plus.fits -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/gaia-small-votable.vot -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/test/files/default_amuse_plummer.hdf5 -> build/lib.linux-x86_64-cpython-311/vaex/test/files
#       copying vaex/datasets/iris.hdf5 -> build/lib.linux-x86_64-cpython-311/vaex/datasets
#       copying vaex/datasets/titanic.hdf5 -> build/lib.linux-x86_64-cpython-311/vaex/datasets
#       running build_ext
#       building 'vaex.vaexfast' extension
#       creating build/temp.linux-x86_64-cpython-311/src
#       g++ -pthread -B /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -fPIC -I/tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include -I/home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include/python3.11 -c src/vaexfast.cpp -o build/temp.linux-x86_64-cpython-311/src/vaexfast.o -std=c++11 -O3 -funroll-loops -Werror=return-type -Wno-unused-parameter -g
#       In file included from /tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include/numpy/ndarraytypes.h:1948,
#                        from /tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                        from /tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                        from src/vaexfast.cpp:31:
#       /tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#          17 | #warning "Using deprecated NumPy API, disable it with " \
#             |  ^~~~~~~
#       src/vaexfast.cpp:743:9: warning: "/*" within comment [-Wcomment]
#         743 |         /**/
#             |
#       src/vaexfast.cpp: In function ‘PyObject* range_check_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:205:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         205 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* find_nan_min_max_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:285:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         285 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* nansum_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:325:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         325 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* sum_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:397:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         397 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* histogram1d_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:536:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         536 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* histogram2d_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:655:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         655 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* histogram2d_f4_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:779:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         779 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* histogram3d_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:896:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         896 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* histogramNd_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:995:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#         995 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* grid_interpolate_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1566:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1566 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* grid_find_edges_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1685:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1685 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* project_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1749:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1749 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* pnpoly_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1802:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1802 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* soneira_peebles_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1861:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1861 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* shuffled_sequence_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:1930:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1930 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In function ‘PyObject* resize_(PyObject*, PyObject*)’:
#       src/vaexfast.cpp:2052:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        2052 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In instantiation of ‘void histogram2d_f4(const float*, const float*, const float*, long long int, bool, bool, bool, Tout*, int, int, double, double, double, double, long long int, long long int) [with Tout = long long int]’:
#       src/vaexfast.cpp:775:33:   required from here
#       src/vaexfast.cpp:665:19: warning: unused variable ‘i_x’ [-Wunused-variable]
#         665 |         long long i_x = offset_x;
#             |                   ^~~
#       src/vaexfast.cpp:666:19: warning: unused variable ‘i_y’ [-Wunused-variable]
#         666 |         long long i_y = offset_y;
#             |                   ^~~
#       src/vaexfast.cpp: In instantiation of ‘PyObject* statisticNd_(PyObject*, PyObject*) [with T = double; int NP_TYPE = 12; PyObject = _object]’:
#       src/vaexfast.cpp:2072:41:   required from here
#       src/vaexfast.cpp:1406:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#        1406 |                 } catch(Error e) {
#             |                               ^
#       src/vaexfast.cpp: In instantiation of ‘PyObject* statisticNd_(PyObject*, PyObject*) [with T = float; int NP_TYPE = 11; PyObject = _object]’:
#       src/vaexfast.cpp:2073:41:   required from here
#       src/vaexfast.cpp:1406:31: warning: catching polymorphic type ‘struct Error’ by value [-Wcatch-value=]
#       src/vaexfast.cpp: In function ‘double double_to_native(double)’:
#       src/vaexfast.cpp:233:16: warning: ‘result_value’ is used uninitialized [-Wuninitialized]
#         233 |         return result_value;
#             |                ^~~~~~~~~~~~
#       src/vaexfast.cpp:227:16: note: ‘result_value’ declared here
#         227 |         double result_value;
#             |                ^~~~~~~~~~~~
#       src/vaexfast.cpp: In function ‘PyObject* statisticNd_(PyObject*, PyObject*) [with T = double; int NP_TYPE = 12]’:
#       src/vaexfast.cpp:1386:38: warning: ‘native’ may be used uninitialized [-Wmaybe-uninitialized]
#        1386 |                                 else if(native != native_current) {
#             |                                      ^~
#       src/vaexfast.cpp:1328:22: note: ‘native’ was declared here
#        1328 |                 bool native;
#             |                      ^~~~~~
#       src/vaexfast.cpp: In function ‘PyObject* statisticNd_(PyObject*, PyObject*) [with T = float; int NP_TYPE = 11]’:
#       src/vaexfast.cpp:1386:38: warning: ‘native’ may be used uninitialized [-Wmaybe-uninitialized]
#        1386 |                                 else if(native != native_current) {
#             |                                      ^~
#       src/vaexfast.cpp:1328:22: note: ‘native’ was declared here
#        1328 |                 bool native;
#             |                      ^~~~~~
#       g++ -pthread -B /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -pthread -B /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/compiler_compat -shared build/temp.linux-x86_64-cpython-311/src/vaexfast.o -o build/lib.linux-x86_64-cpython-311/vaex/vaexfast.cpython-311-x86_64-linux-gnu.so
#       building 'vaex.superstrings' extension
#       g++ -pthread -B /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -fPIC -O2 -isystem /home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -fPIC -I/tmp/pip-build-env-4kazyozt/overlay/lib/python3.11/site-packages/numpy/core/include -Ivendor/pybind11/include -Ivendor/pybind11/include -Ivendor/string-view-lite/include -Ivendor/boost -I/home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include -I/home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/Library/include -I/tmp/pip-install-nzfuxns_/vaex-core_f22fbc9cb75445c6b740aed83b499916/vendor/pcre/Library/include -I/home/mihai_brony/GitHub/master_SistemasInteligentes/.conda/include/python3.11 -c src/string_utils.cpp -o build/temp.linux-x86_64-cpython-311/src/string_utils.o -std=c++11 -O3 -funroll-loops -Werror=return-type -Wno-unused-parameter -g
#       In file included from src/string_utils.cpp:3:
#       src/string_utils.hpp:8:14: error: ‘uint8_t’ does not name a type
#           8 | extern const uint8_t category_index[CHARS >> 8];
#             |              ^~~~~~~
#       src/string_utils.hpp:4:1: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#           3 | #include <regex>
#         +++ |+#include <cstdint>
#           4 |
#       src/string_utils.hpp:9:14: error: ‘uint8_t’ does not name a type
#           9 | extern const uint8_t category_block[][256];
#             |              ^~~~~~~
#       src/string_utils.hpp:9:14: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#       src/string_utils.hpp:10:14: error: ‘uint8_t’ does not name a type
#          10 | const extern uint8_t othercase_index[CHARS >> 8];
#             |              ^~~~~~~
#       src/string_utils.hpp:10:14: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#       src/string_utils.hpp:13:9: error: ‘uint32_t’ does not name a type
#          13 | typedef uint32_t category_t;
#             |         ^~~~~~~~
#       src/string_utils.hpp:13:9: note: ‘uint32_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#       src/string_utils.hpp:14:6: error: expected identifier before ‘:’ token
#          14 | enum : uint8_t {
#             |      ^
#       src/string_utils.hpp:14:6: error: expected unqualified-id before ‘:’ token
#       src/string_utils.hpp:46:6: error: expected identifier before ‘:’ token
#          46 | enum : category_t {
#             |      ^
#       src/string_utils.hpp:46:6: error: expected unqualified-id before ‘:’ token
#       src/string_utils.hpp:88:36: error: ‘Cn’ was not declared in this scope
#          88 | static const int32_t DEFAULT_CAT = Cn;
#             |                                    ^~
#       src/string_utils.hpp:90:8: error: ‘category_t’ does not name a type
#          90 | inline category_t char32_category(char32_t chr) { return chr < CHARS ? 1 << category_block[category_index[chr >> 8]][chr & 0xFF] : DEFAULT_CAT; }
#             |        ^~~~~~~~~~
#       src/string_utils.hpp: In function ‘bool char32_isalpha(char32_t)’:
#       src/string_utils.hpp:92:5: error: ‘category_t’ was not declared in this scope
#          92 |     category_t cat = char32_category(chr);
#             |     ^~~~~~~~~~
#       src/string_utils.hpp:93:13: error: ‘cat’ was not declared in this scope
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |             ^~~
#       src/string_utils.hpp:93:20: error: ‘Lm’ was not declared in this scope; did you mean ‘tm’?
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                    ^~
#             |                    tm
#       src/string_utils.hpp:93:35: error: ‘Lt’ was not declared in this scope
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                   ^~
#       src/string_utils.hpp:93:50: error: ‘Lu’ was not declared in this scope
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                  ^~
#       src/string_utils.hpp:93:65: error: ‘Ll’ was not declared in this scope
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                                 ^~
#       src/string_utils.hpp:93:80: error: ‘Lo’ was not declared in this scope
#          93 |     return (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                                                ^~
#       src/string_utils.hpp: In function ‘bool char32_isalnum(char32_t)’:
#       src/string_utils.hpp:97:5: error: ‘category_t’ was not declared in this scope
#          97 |     category_t cat = char32_category(chr);
#             |     ^~~~~~~~~~
#       src/string_utils.hpp:98:21: error: ‘cat’ was not declared in this scope
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                     ^~~
#       src/string_utils.hpp:98:28: error: ‘Lm’ was not declared in this scope; did you mean ‘tm’?
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                            ^~
#             |                            tm
#       src/string_utils.hpp:98:43: error: ‘Lt’ was not declared in this scope
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                           ^~
#       src/string_utils.hpp:98:58: error: ‘Lu’ was not declared in this scope
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                          ^~
#       src/string_utils.hpp:98:73: error: ‘Ll’ was not declared in this scope
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                                         ^~
#       src/string_utils.hpp:98:88: error: ‘Lo’ was not declared in this scope
#          98 |     bool isalpha = (cat == Lm) || (cat == Lt) || (cat == Lu) || (cat == Ll) || (cat == Lo);
#             |                                                                                        ^~
#       src/string_utils.hpp:104:26: error: ‘Nd’ was not declared in this scope
#         104 |     bool isnum = (cat == Nd) || (cat == Nl) || (cat == No);
#             |                          ^~
#       src/string_utils.hpp:104:41: error: ‘Nl’ was not declared in this scope
#         104 |     bool isnum = (cat == Nd) || (cat == Nl) || (cat == No);
#             |                                         ^~
#       src/string_utils.hpp:104:56: error: ‘No’ was not declared in this scope
#         104 |     bool isnum = (cat == Nd) || (cat == Nl) || (cat == No);
#             |                                                        ^~
#       src/string_utils.hpp: In function ‘char32_t char32_uppercase(char32_t)’:
#       src/string_utils.hpp:109:46: error: ‘othercase_index’ was not declared in this scope; did you mean ‘othercase_type’?
#         109 |         char32_t othercase = othercase_block[othercase_index[chr >> 8]][chr & 0xFF];
#             |                                              ^~~~~~~~~~~~~~~
#             |                                              othercase_type
#       src/string_utils.hpp: In function ‘char32_t char32_lowercase(char32_t)’:
#       src/string_utils.hpp:122:46: error: ‘othercase_index’ was not declared in this scope; did you mean ‘othercase_type’?
#         122 |         char32_t othercase = othercase_block[othercase_index[chr >> 8]][chr & 0xFF];
#             |                                              ^~~~~~~~~~~~~~~
#             |                                              othercase_type
#       src/string_utils.cpp: At global scope:
#       src/string_utils.cpp:33:7: error: ‘uint8_t’ does not name a type
#          33 | const uint8_t category_index[CHARS >> 8] = {
#             |       ^~~~~~~
#       src/string_utils.cpp:4:1: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#           3 | #include "string_utils.hpp"
#         +++ |+#include <cstdint>
#           4 |
#       src/string_utils.cpp:42:7: error: ‘uint8_t’ does not name a type
#          42 | const uint8_t category_block[][256] = {
#             |       ^~~~~~~
#       src/string_utils.cpp:42:7: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#       src/string_utils.cpp:174:7: error: ‘uint8_t’ does not name a type
#         174 | const uint8_t othercase_index[CHARS >> 8] = {
#             |       ^~~~~~~
#       src/string_utils.cpp:174:7: note: ‘uint8_t’ is defined in header ‘<cstdint>’; did you forget to ‘#include <cstdint>’?
#       error: command '/usr/bin/g++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for vaex-core
# Failed to build vaex-core
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (vaex-core)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import polars as pl
import duckdb
import vaex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       2 import polars as pl
#       3 import duckdb
# ----> 4 import vaex
#
# ModuleNotFoundError: No module named 'vaex'

# %%
import os

# %% [markdown]
# ## LOADING & TRANSFORMING DATA
#
# Profiling code (guide):
# https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/01.07-Timing-and-Profiling.ipynb

# %%
# !wget https://krono.act.uji.es/IDIA/loans.csv.gz
# Out:
# --2024-10-14 16:48:40--  https://krono.act.uji.es/IDIA/loans.csv.gz
# Resolving krono.act.uji.es (krono.act.uji.es)... 150.128.97.37
# Connecting to krono.act.uji.es (krono.act.uji.es)|150.128.97.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82624417 (79M) [application/x-gzip]
# Saving to: ‘loans.csv.gz’
#
# loans.csv.gz        100%[===================>]  78.80M  7.06MB/s    in 14s
#
# 2024-10-14 16:48:55 (5.53 MB/s) - ‘loans.csv.gz’ saved [82624417/82624417]

# %%
# !gunzip loans.csv.gz

# %% [markdown]
# ### PANDAS

# %%
df = pd.read_csv('./loans.csv')  #use timeit for several executions

# %%
df.head()
# Out:
#                                uuid                          use_uuid  \
# 0  30300405f1fb4a2e8ebeef4377b2fea1                               NaN
# 1  3030296398be45ca9ec387d146c10ef2  024cbe02bf494e4f9125ede5a21db1a8
# 2  303035331fe14b8797a8488c85b7d26a  5edc5b39c72047a6b34e17426495c99a
# 3  30303bfde83e450e93580ca739f1cad2                               NaN
# 4  30303e3ff4b84b4da053b7b605a0d9d4                               NaN
#
#                        bicycle_uuid                       anchor_uuid  \
# 0  fb135edf71a74ca48085d6fa4b719c76  f239242f253c43f69f0fd655cdb9e898
# 1  57ebb2215f2a45f0a1c0c5a97f6fde79  1042bbe5c80549c987e51f04d1cb9285
# 2  30ccded725e94a6a88dfd9456b4cd6d0  f8c081df1b524c1f8db348da809ceff3
# 3  1d06622f183d485297aa91a0da25ff40  64b4da4811624d77a3bf15225ed9a50f
# 4  66b8a22235a345b78d19899cd37bc277  f1d0b0627c7d4cd698c16e94a7a7ab2b
#
#           date_created type_access
# 0  2017-04-12 17:06:28     UNKNOWN
# 1  2017-05-11 18:03:53     UNKNOWN
# 2  2017-04-11 21:02:45     UNKNOWN
# 3  2017-05-09 08:24:05     UNKNOWN
# 4  2017-04-22 08:31:42     UNKNOWN

# %% [markdown]
# **Using the Apache Parquet format**
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_parquet.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_parquet.html

# %%
if not os.path.exists('loans.parquet'):
  df.to_parquet('loans.parquet') #, compression='gzip')
  #transform to parquet format -> compression='snappy' by default

# %%
# !ls -GFlash *.*
# Out:
# 235M -rw-r--r-- 1 root 235M Oct 13  2023 loans.csv
#  74M -rw-r--r-- 1 root  74M Oct 14 16:53 loans.parquet
#  47M -rw-r--r-- 1 root  47M Oct 14 16:51 loans.parquet.gzip

# %%
# %timeit df = pd.read_parquet('./loans.parquet')
# Out:
# 2.76 s ± 227 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# **Predicate Push Down (filter while loading)**

# %%
del df  ## free memory of the previous dataframe

df = pd.read_parquet('./loans.parquet', filters=[("date_created",">","2017-05-01 00:00:00"),("date_created","<","2017-06-01 00:00:00")])

# %%
df.head()
# Out:
#                                uuid                          use_uuid  \
# 0  3030296398be45ca9ec387d146c10ef2  024cbe02bf494e4f9125ede5a21db1a8
# 1  30303bfde83e450e93580ca739f1cad2                              None
# 2  30304d9c5b1445a0a6cebd9a344b30bf                              None
# 3  3030632449df4522acb7707f8e5191b3  178e8d38526347efb7c53bd01110fa70
# 4  3030667945d541b5964e72b9de3c10e1                              None
#
#                        bicycle_uuid                       anchor_uuid  \
# 0  57ebb2215f2a45f0a1c0c5a97f6fde79  1042bbe5c80549c987e51f04d1cb9285
# 1  1d06622f183d485297aa91a0da25ff40  64b4da4811624d77a3bf15225ed9a50f
# 2  5813bd5f79b74cbfb267d164875ad08a  33677684d3c349c8b21d4303e838a1cd
# 3  388f697b5e904f4b9882fdbe432356e0  39fec48744294a4099102cd9f2800636
# 4  e968ef5a4f61482a9c0b26b3dd174f14  ec917a85a7ab44659ab11ce702c830d8
#
#           date_created type_access
# 0  2017-05-11 18:03:53     UNKNOWN
# 1  2017-05-09 08:24:05     UNKNOWN
# 2  2017-05-24 20:28:43     UNKNOWN
# 3  2017-05-06 16:25:29     UNKNOWN
# 4  2017-05-29 03:23:40     UNKNOWN

# %%
df_taxi = pd.read_parquet('/content/yellow_tripdata_2023-01.parquet')

df_taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# memory usage: 444.6+ MB

# %% [markdown]
# ## PANDAS

# %% [markdown]
# **Exercise 1:** Using the parquet file, load only the column *date_created* for those rows with *use_uuid* different from None. With the loaded data, get the
# total loans per [day of the week](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.dayofweek.html).

# %%
## del df

# %% [markdown]
# **Exercise 2:** Using the parquet file, load only the column *bicycle_uuis* and get the top 100 most used bicycles along with their total loans.

# %%
## del df

# %% [markdown]
# ### POLARS
#
# Cheat Sheet:
# https://colab.research.google.com/github/FranzDiebold/polars-cheat-sheet/blob/main/polars-cheat-sheet.ipynb

# %%
## Do the same steps with polars (except creating the parquet file)

# %% [markdown]
# ### VAEX
#
# Tutorial: https://vaex.io/docs/tutorials.html

# %%
## Do the same steps with Vaex (except creating the parquet file)

# %% [markdown]
# ## DUCKDB
#
# https://duckdb.org/docs/sql/introduction.html
#
# Python: https://duckdb.org/docs/api/python/overview.html

# %%
## Do the same steps with DuckDB (except creating the parquet file)

# %% [markdown]
# ### SUMMARY OF RESULTS
#
# Report the execution times for the different frameworks:
# - Loading CSV vs. Parquet
# - Loading Parquet with filters
# - Performing the required aggregations (Exercises 1 & 2)

# %%
# Write a summary of the results obtained in the previous evaluations

# %% [markdown]
# ## NEW YORK TRIP DATA
#
# ORIGINAL DATA:
# -   NYC Yellow Taxi (original): https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# KAGGLE (in CSV and only 2015):
# -   Kaggle: https://www.kaggle.com/datasets/elemento/nyc-yellow-taxi-trip-data
#
# DATA FOR THE EXERCISE (place these files into a folder and load the whole folder of parquets with "folder/*"):
# -   Server: https://krono.act.uji.es/IDIA/yellow_tripdata_2015-01.parquet
# -   Server: https://krono.act.uji.es/IDIA/yellow_tripdata_2023-01.parquet

# %% [markdown]
# **Exercise 3**: Compare the number of trips occurred in January 2015 and January 2023. Choose the best framework you consider for this task, and use predicates to get only what you need for the analysis.

# %%
# your code here
